# %%
import pandas as pd
import os 
from dotenv import load_dotenv
from pathlib import Path
import json

# %%
load_dotenv()

markets_json_path = Path(os.getenv("DATASETS_DIR")) / "raw" / "polymarket" / "markets.json"

# %%
with open(markets_json_path, "r", encoding="utf-8") as f:
    market_data = json.load(f)

# %%
markets_df = pd.json_normalize(market_data)

# %%
markets_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 176270 entries, 0 to 176269
# Data columns (total 74 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   id                                176270 non-null  str
#  1   version                           176270 non-null  str
#  2   slug                              176270 non-null  str
#  3   condition_id                      176226 non-null  str
#  4   question                          176270 non-null  str
#  5   group_item_title                  169547 non-null  str
#  6   description                       176270 non-null  str
#  7   category                          0 non-null       object
#  8   image                             126737 non-null  str
#  9   icon                              126569 non-null  str
#  10  events                            176270 non-null  object
#  11  tags                              176270 non-null  object
#  12  position_ids                      176270 non-null  object
#  13  state.active                      176270 non-null  bool
#  14  state.closed                      176270 non-null  bool
#  15  state.archived                    176270 non-null  bool
#  16  state.combo_status                176270 non-null  str
#  17  state.accepting_orders            176169 non-null  object
#  18  state.enable_order_book           176270 non-null  bool
#  19  state.neg_risk                    176270 non-null  bool
#  20  state.start_date                  176206 non-null  str
#  21  state.end_date                    174521 non-null  str
#  22  state.closed_time                 0 non-null       object
#  23  outcomes.yes.label                176270 non-null  str
#  24  outcomes.yes.token_id             176226 non-null  str
#  25  outcomes.yes.position_id          122331 non-null  str
#  26  outcomes.yes.price                176158 non-null  str
#  27  outcomes.no.label                 176270 non-null  str
#  28  outcomes.no.token_id              176226 non-null  str
#  29  outcomes.no.position_id           122331 non-null  str
#  30  outcomes.no.price                 176158 non-null  str
#  31  metrics.volume                    41620 non-null   str
#  32  metrics.volume_num                41620 non-null   str
#  33  metrics.volume_24hr               18358 non-null   str
#  34  metrics.volume_1wk                18424 non-null   str
#  35  metrics.volume_1mo                18429 non-null   str
#  36  metrics.volume_1yr                18430 non-null   str
#  37  metrics.volume_amm                119 non-null     str
#  38  metrics.volume_clob               41333 non-null   str
#  39  metrics.liquidity                 154834 non-null  str
#  40  metrics.liquidity_num             154834 non-null  str
#  41  metrics.liquidity_clob            154834 non-null  str
#  42  prices.best_bid                   139649 non-null  str
#  43  prices.best_ask                   176270 non-null  str
#  44  prices.last_trade_price           35098 non-null   str
#  45  prices.spread                     176270 non-null  str
#  46  prices.one_hour_price_change      37506 non-null   str
#  47  prices.one_day_price_change       69272 non-null   str
#  48  prices.one_week_price_change      54245 non-null   str
#  49  prices.one_month_price_change     23618 non-null   str
#  50  prices.one_year_price_change      235 non-null     str
#  51  trading.minimum_order_size        176241 non-null  str
#  52  trading.minimum_tick_size         176270 non-null  str
#  53  trading.seconds_delay             134893 non-null  float64
#  54  trading.fees_enabled              176270 non-null  bool
#  55  trading.fee_type                  175253 non-null  str
#  56  trading.fee_schedule.exponent     175253 non-null  float64
#  57  trading.fee_schedule.rate         175253 non-null  str
#  58  trading.fee_schedule.taker_only   175253 non-null  object
#  59  trading.fee_schedule.rebate_rate  175253 non-null  str
#  60  resolution.question_id            176226 non-null  str
#  61  resolution.neg_risk_request_id    67240 non-null   str
#  62  resolution.uma_resolution_status  3846 non-null    str
#  63  resolution.source                 140742 non-null  str
#  64  resolution.resolved_by            173024 non-null  str
#  65  rewards.clob_rewards              18232 non-null   object
#  66  rewards.rewards_min_size          176270 non-null  str
#  67  rewards.rewards_max_spread        176270 non-null  float64
#  68  rewards.holding_rewards_enabled   176270 non-null  bool
#  69  sports.sports_market_type         126199 non-null  str
#  70  sports.line                       76993 non-null   float64
#  71  sports.game_id                    660 non-null     str
#  72  sports.game_start_time            131678 non-null  str
#  73  trading.fee_schedule              0 non-null       float64
# dtypes: bool(7), float64(5), object(8), str(54)
# memory usage: 469.1+ MB

# %%
# Out:
# 176252    2026-09-13 18:18:52.629550+00:00
# 176248    2026-09-13 18:18:49.993074+00:00
# 176269           2026-09-13 18:18:20+00:00
# 176259    2026-09-13 18:17:58.712931+00:00
# 176260    2026-09-13 18:16:49.600622+00:00
# 176261    2026-09-13 18:16:18.578945+00:00
# 176268           2026-09-13 18:15:50+00:00
# 176267           2026-09-13 18:15:20+00:00
# 176263    2026-09-13 18:15:15.264440+00:00
# 176266           2026-09-13 18:14:25+00:00
# 176264           2026-09-13 18:14:17+00:00
# 176265           2026-09-13 18:14:17+00:00
# 176256    2026-09-13 18:14:14.010274+00:00
# 176262    2026-09-13 18:14:13.722474+00:00
# 176253    2026-09-13 18:14:11.602499+00:00
# 176207    2026-09-13 18:13:40.286280+00:00
# 176201    2026-09-13 18:13:36.184038+00:00
# 176254    2026-09-13 18:12:40.476277+00:00
# 176250    2026-09-13 18:12:28.483713+00:00
# 176249    2026-09-13 18:11:31.821494+00:00
# 176246    2026-09-13 18:10:52.535886+00:00
# 176255    2026-09-13 18:10:36.622299+00:00
# 176251    2026-09-13 18:09:48.265091+00:00
# 176257    2026-09-13 18:09:23.335801+00:00
# 176247    2026-09-13 18:09:12.156122+00:00
# 176258    2026-09-13 18:08:57.272213+00:00
# 176245    2026-09-13 18:08:55.176598+00:00
# 176204    2026-09-13 18:07:21.322389+00:00
# 176244           2026-09-13 18:07:18+00:00
# 175941    2026-09-13 18:06:03.616791+00:00
# Name: state.start_date, dtype: str
